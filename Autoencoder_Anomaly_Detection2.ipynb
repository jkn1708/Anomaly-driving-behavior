# %% [markdown]
# ## 운전자 이상행동 탐지

# %%
# import libraries
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import joblib
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import seed
import tensorflow as tf

from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from keras.models import Model
from keras import regularizers

# set random seed
seed(10)
tf.random.set_seed(10)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 데이터 로딩 및 커서포인터 설정

# %%
import sqlite3 as s

conn1 = s.connect('data/base4.sqlite') 
conn2 = s.connect('data/anomal4.sqlite')
with open('data/base4.sqlite', 'r') as f:
    train = conn1.cursor()
with open('data/anomal4.sqlite', 'r') as f:
    test = conn2.cursor()

# %%
train = pd.read_sql_query("SELECT stime FROM MILANE WHERE hspeed > 10 ",conn1)
test = pd.read_sql_query("SELECT stime FROM MILANE WHERE hspeed > 10 ",conn2)

# %%
# train data plot
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['stime'], label='stime', color='blue', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Base Data set', fontsize=16)
ax.set_xlabel('data')
ax.set_ylabel('stop time')
plt.show()

# %%
print("Training dataset shape:", train.shape)
print("Test dataset shape:", test.shape)
# Out:
# Training dataset shape: (364, 1)
# Test dataset shape: (360, 1)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(train)
X_test = scaler.transform(test)
X_train
scaler_filename = "data/real_scaler_data"
joblib.dump(scaler, scaler_filename)
# Out:
# ['data/real_scaler_data']

# %%
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
print("Training data shape:", X_train.shape)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (364, 1, 1)
# Test data shape: (360, 1, 1)

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(24, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(12, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(12, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(24, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 1)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 24)             2496
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 12)                1776
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 1, 12)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 12)             1200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1, 24)             3552
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 1, 1)              25
# =================================================================
# Total params: 9,049
# Trainable params: 9,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model to the data
nb_epochs = 200
batch_size = 10
history = model.fit(X_train, X_train, epochs=nb_epochs, batch_size=batch_size
                ).history
# Out:
# Epoch 1/200
# 364/364 [==============================] - 1s 3ms/step - loss: 0.2714
# Epoch 2/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.2658
# Epoch 3/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.2588
# Epoch 4/200
# 364/364 [==============================] - 0s 188us/step - loss: 0.2431
# Epoch 5/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.1825
# Epoch 6/200
# 364/364 [==============================] - 0s 188us/step - loss: 0.1230
# Epoch 7/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0942
# Epoch 8/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0841
# Epoch 9/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0795
# Epoch 10/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0772
# Epoch 11/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0796
# Epoch 12/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0727
# Epoch 13/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0679
# Epoch 14/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0646
# Epoch 15/200
# 364/364 [==============================] - 0s 214us/step - loss: 0.0631
# Epoch 16/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0600
# Epoch 17/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0562
# Epoch 18/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0520
# Epoch 19/200
# 364/364 [==============================] - 0s 207us/step - loss: 0.0495
# Epoch 20/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0475
# Epoch 21/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0448
# Epoch 22/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0410
# Epoch 23/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0386
# Epoch 24/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0351
# Epoch 25/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0331
# Epoch 26/200
# 364/364 [==============================] - 0s 219us/step - loss: 0.0262
# Epoch 27/200
# 364/364 [==============================] - 0s 227us/step - loss: 0.0223
# Epoch 28/200
# 364/364 [==============================] - 0s 216us/step - loss: 0.0185
# Epoch 29/200
# 364/364 [==============================] - 0s 225us/step - loss: 0.0136
# Epoch 30/200
# 364/364 [==============================] - 0s 227us/step - loss: 0.0085
# Epoch 31/200
# 364/364 [==============================] - 0s 221us/step - loss: 0.0064
# Epoch 32/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0053
# Epoch 33/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0044
# Epoch 34/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0044
# Epoch 35/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0038
# Epoch 36/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0040
# Epoch 37/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0048
# Epoch 38/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0038
# Epoch 39/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0027
# Epoch 40/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0041
# Epoch 41/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0034
# Epoch 42/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0029
# Epoch 43/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0023
# Epoch 44/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0032
# Epoch 45/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0025
# Epoch 46/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0026
# Epoch 47/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0038
# Epoch 48/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0027
# Epoch 49/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0018
# Epoch 50/200
# 364/364 [==============================] - 0s 219us/step - loss: 0.0026
# Epoch 51/200
# 364/364 [==============================] - 0s 222us/step - loss: 0.0030
# Epoch 52/200
# 364/364 [==============================] - 0s 216us/step - loss: 0.0019
# Epoch 53/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0023
# Epoch 54/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0019
# Epoch 55/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0016
# Epoch 56/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0019
# Epoch 57/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0016
# Epoch 58/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0020
# Epoch 59/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0041
# Epoch 60/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0024
# Epoch 61/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0018
# Epoch 62/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0018
# Epoch 63/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0028
# Epoch 64/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0041
# Epoch 65/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0021
# Epoch 66/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0014
# Epoch 67/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0023
# Epoch 68/200
# 364/364 [==============================] - 0s 219us/step - loss: 0.0022
# Epoch 69/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0029
# Epoch 70/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0015
# Epoch 71/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0023
# Epoch 72/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0020
# Epoch 73/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0013
# Epoch 74/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0017
# Epoch 75/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0012
# Epoch 76/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0016
# Epoch 77/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0022
# Epoch 78/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0017
# Epoch 79/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0014
# Epoch 80/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0022
# Epoch 81/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0017
# Epoch 82/200
# 364/364 [==============================] - 0s 211us/step - loss: 0.0016
# Epoch 83/200
# 364/364 [==============================] - 0s 208us/step - loss: 0.0020
# Epoch 84/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0020
# Epoch 85/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0020
# Epoch 86/200
# 364/364 [==============================] - 0s 208us/step - loss: 0.0018
# Epoch 87/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0015
# Epoch 88/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0034
# Epoch 89/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0034
# Epoch 90/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0025
# Epoch 91/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0021
# Epoch 92/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0016
# Epoch 93/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0015
# Epoch 94/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0026
# Epoch 95/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0025
# Epoch 96/200
# 364/364 [==============================] - 0s 222us/step - loss: 0.0016
# Epoch 97/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0013
# Epoch 98/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0017
# Epoch 99/200
# 364/364 [==============================] - 0s 227us/step - loss: 0.0017
# Epoch 100/200
# 364/364 [==============================] - 0s 211us/step - loss: 0.0015
# Epoch 101/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0012
# Epoch 102/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0013
# Epoch 103/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0024
# Epoch 104/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0018
# Epoch 105/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0020
# Epoch 106/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0018
# Epoch 107/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0013
# Epoch 108/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0017
# Epoch 109/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0017
# Epoch 110/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0015
# Epoch 111/200
# 364/364 [==============================] - 0s 219us/step - loss: 0.0018
# Epoch 112/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0020
# Epoch 113/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0031
# Epoch 114/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0011
# Epoch 115/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0019
# Epoch 116/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0015
# Epoch 117/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0016
# Epoch 118/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0020
# Epoch 119/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0013
# Epoch 120/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0011
# Epoch 121/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0011
# Epoch 122/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0015
# Epoch 123/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0014
# Epoch 124/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0018
# Epoch 125/200
# 364/364 [==============================] - 0s 184us/step - loss: 0.0024
# Epoch 126/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0014
# Epoch 127/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0019
# Epoch 128/200
# 364/364 [==============================] - 0s 184us/step - loss: 0.0023
# Epoch 129/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0019
# Epoch 130/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0020
# Epoch 131/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0013
# Epoch 132/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0018
# Epoch 133/200
# 364/364 [==============================] - 0s 184us/step - loss: 0.0018
# Epoch 134/200
# 364/364 [==============================] - 0s 189us/step - loss: 9.3762e-04
# Epoch 135/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0017
# Epoch 136/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0022
# Epoch 137/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0034
# Epoch 138/200
# 364/364 [==============================] - 0s 216us/step - loss: 0.0019
# Epoch 139/200
# 364/364 [==============================] - 0s 214us/step - loss: 0.0018
# Epoch 140/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0015
# Epoch 141/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0012
# Epoch 142/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0031
# Epoch 143/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0025
# Epoch 144/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0010
# Epoch 145/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0015
# Epoch 146/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0017
# Epoch 147/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0019
# Epoch 148/200
# 364/364 [==============================] - 0s 208us/step - loss: 0.0013
# Epoch 149/200
# 364/364 [==============================] - 0s 208us/step - loss: 0.0018
# Epoch 150/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0013
# Epoch 151/200
# 364/364 [==============================] - 0s 211us/step - loss: 0.0015
# Epoch 152/200
# 364/364 [==============================] - 0s 225us/step - loss: 0.0016
# Epoch 153/200
# 364/364 [==============================] - 0s 211us/step - loss: 0.0022
# Epoch 154/200
# 364/364 [==============================] - 0s 236us/step - loss: 0.0020
# Epoch 155/200
# 364/364 [==============================] - 0s 214us/step - loss: 0.0030
# Epoch 156/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0029
# Epoch 157/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0020
# Epoch 158/200
# 364/364 [==============================] - 0s 203us/step - loss: 0.0016
# Epoch 159/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0027
# Epoch 160/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0015
# Epoch 161/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0021
# Epoch 162/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0015
# Epoch 163/200
# 364/364 [==============================] - 0s 197us/step - loss: 0.0015
# Epoch 164/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0012
# Epoch 165/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0016
# Epoch 166/200
# 364/364 [==============================] - 0s 219us/step - loss: 0.0013
# Epoch 167/200
# 364/364 [==============================] - 0s 219us/step - loss: 0.0016
# Epoch 168/200
# 364/364 [==============================] - 0s 205us/step - loss: 0.0012
# Epoch 169/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0018
# Epoch 170/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0020
# Epoch 171/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0028
# Epoch 172/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0015
# Epoch 173/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0011
# Epoch 174/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0013
# Epoch 175/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0018
# Epoch 176/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0019
# Epoch 177/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0011
# Epoch 178/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0013
# Epoch 179/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0013
# Epoch 180/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0026
# Epoch 181/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0017
# Epoch 182/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0019
# Epoch 183/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0019
# Epoch 184/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0029
# Epoch 185/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0014
# Epoch 186/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0013
# Epoch 187/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0032
# Epoch 188/200
# 364/364 [==============================] - 0s 184us/step - loss: 0.0031
# Epoch 189/200
# 364/364 [==============================] - 0s 195us/step - loss: 0.0025
# Epoch 190/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0018
# Epoch 191/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0043
# Epoch 192/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0019
# Epoch 193/200
# 364/364 [==============================] - 0s 192us/step - loss: 0.0016
# Epoch 194/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0024
# Epoch 195/200
# 364/364 [==============================] - 0s 189us/step - loss: 0.0023
# Epoch 196/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0016
# Epoch 197/200
# 364/364 [==============================] - 0s 200us/step - loss: 0.0019
# Epoch 198/200
# 364/364 [==============================] - 0s 214us/step - loss: 0.0011
# Epoch 199/200
# 364/364 [==============================] - 0s 186us/step - loss: 0.0014
# Epoch 200/200
# 364/364 [==============================] - 0s 184us/step - loss: 0.0022

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)

ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Distribution of Loss Function

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=train.columns)
X_pred.index = train.index

scored = pd.DataFrame(index=train.index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde = True, color = 'blue');
plt.xlim([0.0,0.03])
# Out:
# C:\Users\jkn17\anaconda3\envs\test\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 0.03)

# %%
print('anomaly threshold = {}'.format(np.percentile(scored,100)))
threshold = np.percentile(scored,100)

X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=test.columns)
X_pred.index = test.index

scored = pd.DataFrame(index=test.index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = threshold
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
# anomaly threshold = 0.006128251552581676
#    Loss_mae  Threshold  Anomaly
# 0  0.000328   0.006128    False
# 1  0.000015   0.006128    False
# 2  0.000098   0.006128    False
# 3  0.000212   0.006128    False
# 4  0.000239   0.006128    False

# %%
# test set에 대한 결과
scored.plot(logy=True,  figsize=(16,9), ylim=[0,1.10], color=['blue','red'])
# Out:
# C:\Users\jkn17\anaconda3\envs\test\lib\site-packages\pandas\plotting\_matplotlib\core.py:486: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(self.ylim)
# <AxesSubplot:>

# %%
#whole test data
test_ = pd.read_sql_query("SELECT stime FROM MILANE WHERE hspeed > 10 ",conn2)

#make plot
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(test_['stime'], label='stime', color='blue', animated = True, linewidth=1)
ax.scatter(test_[scored['Anomaly']==1]['stime'].index,test_[scored['Anomaly']==1]['stime'],label='anomal',marker='.', color='red')
plt.legend(loc='lower left')
ax.set_title('Result Data', fontsize=16)
ax.set_ylabel('stop time(sec)')
ax.set_xlabel('data')

plt.show()

# %%
# save all model information, including weights, in h5 format
model.save("model.h5")
print("Model saved")
# Out:
# Model saved
